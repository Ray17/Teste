# %%
# %matplotlib inline

import numpy as np 
import matplotlib.pyplot as plt
from scipy.optimize import least_squares
A=4.79
B=0.197
C=39.0
def v(t):
    return (A*(1-np.exp(-C*t))+B)
t=np.linspace(11,43.2,1000)

#EXTRAÇÃO DOS DADOS EXPERIMENTAIS

file=open("C:\\Users\\Bruno Lima\\Desktop\\TEMPOC1.txt",'r')
T=np.loadtxt(file)
# T=[]
#for line in file:
 #   T.append(float(line))
file.close()
# V=[]
file=open("C:\\Users\\Bruno Lima\\Desktop\\TENSAOV1.txt",'r')
#for line in file:
 #   V.append(float(line))
V=np.loadtxt(file)
file.close()

#=================================================#



plt.rcParams['figure.figsize']=(15,5)
plt.rcParams.update({'font.size':17})
#plt.plot(t,v(t),label=r'$4.79*(1-e^{-39*t})+0.197$')
plt.plot(T,V,'ro',label=r'DADOS EXPERIMENTAIS')
plt.legend(loc='best',fontsize=20)
plt.title('Carregamento do capacitor $C_2$=24,1 $\mu F$')
plt.xlabel('tempo t(s)',fontsize=18)
plt.ylabel('tensão V(t)',fontsize=18)
plt.show()
